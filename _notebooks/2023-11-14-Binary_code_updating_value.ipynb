# %% [markdown]
# ---
# comments: true
# layout: posts
# title: Binary work
# description: a javascript and python code that converts binary numbers into regular numbers
# type: hacks
# courses: { compsci: {week: 13} }
# ---

# %% [markdown]
# ## code that displays the total value of the binary numbers

# %%
// Create variables
let slots = [0, 0, 0, 0, 0, 0, 0, 0];
let totalValue = 0;

// Get user input for binary numbers
for (let i = 0; i < 8; i++) {
    let binaryDigit = prompt(`Insert a binary digit (0 or 1) for position ${i + 1}: `);

    if (binaryDigit === '0') {
        slots[i] = 0;
    } else if (binaryDigit === '1') {
        slots[i] = Math.pow(2, 7 - i);
    } else {
        alert("Invalid input. Please enter either 0 or 1.");
        throw new Error("Invalid input.");
    }
}

// Calculate total value
totalValue = slots.reduce((sum, value) => sum + value, 0);

// Print the total value
if (totalValue > 254) {
    console.log("Total value: ff");
} else {
    console.log("Total value:", totalValue);
}
# Out:
#   File "/tmp/ipykernel_48779/518579622.py", line 1
#     // Create variables
#     ^
# SyntaxError: invalid syntax

# %%
# prototype
# creates variables
slot1 = 0
slot2 = 0
slot3 = 0
slot4 = 0
slot5 = 0
slot6 = 0
slot7 = 0
slot8 = 0
totalvalue = 0

# creates user input to decide binary numbers
first = input("insert a number either 1 or 0")
second = input("insert a number that is either 1 or 0")
third = input("insert a number that is either 1 or 0")
fourth = input("insert a number that is either 1 or 0")
fifth = input("insert a number that is either 1 or 0")
sixth = input("insert a number that is either 1 or 0")
seventh = input("insert a number that is either 1 or 0")
eight = input("insert a number that is either 1 or 0")

# created if statements to determine the values of the variables based on the input
if first == '0':
    slot1 = 0
elif first == '1':
    slot1 = 128
else:
    print("invalid input")

if second == '0':
    slot2 = 0
elif second == '1':
    slot2 = 64
else:
    print("invalid input")

if third == '0':
    slot3 = 0
elif third == '1':
    slot3 = 32
else:
    print("invalid input")
    
if fourth == '0':
    slot4 = 0
elif fourth == '1':
    slot4 = 16
else:
    print("invalid input")

if fifth == '0':
    slot5 = 0
elif fifth == '1':
    slot5 = 8
else:
    print("invalid input")

if sixth == '0':
    slot6 = 0
elif sixth == '1':
    slot6 = 4
else:
    print("invalid input")

if seventh == '0':
    slot7 = 0
elif seventh == '1':
    slot7 = 2
else:
    print("invalid input")

if eight == '0':
    slot8 = 0
elif eight == '1':
    slot8 = 1
else:
    print("invalid input")

# does math to determine total value
totalvalue = slot1 + slot2 + slot3 + slot4 + slot5 + slot6 + slot7 +slot8
if totalvalue > 254:
    print("total value: ff")
else:
    print(totalvalue)
# Out:
# 252

# %%
// Create variables
let slot1 = 0;
let slot2 = 0;
let slot3 = 0;
let slot4 = 0;
let slot5 = 0;
let slot6 = 0;
let slot7 = 0;
let slot8 = 0;
let totalValue = 0;

// Get user input for binary numbers
let first = prompt("Insert a number either 1 or 0");
let second = prompt("Insert a number that is either 1 or 0");
let third = prompt("Insert a number that is either 1 or 0");
let fourth = prompt("Insert a number that is either 1 or 0");
let fifth = prompt("Insert a number that is either 1 or 0");
let sixth = prompt("Insert a number that is either 1 or 0");
let seventh = prompt("Insert a number that is either 1 or 0");
let eighth = prompt("Insert a number that is either 1 or 0");

// Create if statements to determine the values of the variables based on the input
if (first === '0') {
    slot1 = 0;
} else if (first === '1') {
    slot1 = 128;
} else {
    console.log("Invalid input");
}

if (second === '0') {
    slot2 = 0;
} else if (second === '1') {
    slot2 = 64;
} else {
    console.log("Invalid input");
}

if (third === '0') {
    slot3 = 0;
} else if (third === '1') {
    slot3 = 32;
} else {
    console.log("Invalid input");
}

if (fourth === '0') {
    slot4 = 0;
} else if (fourth === '1') {
    slot4 = 16;
} else {
    console.log("Invalid input");
}

if (fifth === '0') {
    slot5 = 0;
} else if (fifth === '1') {
    slot5 = 8;
} else {
    console.log("Invalid input");
}

if (sixth === '0') {
    slot6 = 0;
} else if (sixth === '1') {
    slot6 = 4;
} else {
    console.log("Invalid input");
}

if (seventh === '0') {
    slot7 = 0;
} else if (seventh === '1') {
    slot7 = 2;
} else {
    console.log("Invalid input");
}

if (eighth === '0') {
    slot8 = 0;
} else if (eighth === '1') {
    slot8 = 1;
} else {
    console.log("Invalid input");
}

// Do math to determine total value
totalValue = slot1 + slot2 + slot3 + slot4 + slot5 + slot6 + slot7 + slot8;

// Print the total value
if (totalValue > 254) {
    console.log("Total value: ff");
} else {
    console.log("Total value:", totalValue);
}
# Out:
#   File "/tmp/ipykernel_48779/819413639.py", line 1
#     let slot1 = 0;
#         ^
# SyntaxError: invalid syntax
